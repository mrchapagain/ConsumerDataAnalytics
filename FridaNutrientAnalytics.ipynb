# %% [markdown]
# # Frida Nutrient Analytics

# %%
import pandas as pd
# Import data
data_link= "FridaNutrientData.xlsx"

# %%
"""#col_names= ['Gruppe', 'Navn', 'Svind_%', 'Energi_kJ', 'Energi_kcal', 'Nitrogen-til-proteinfaktor', 'Nitrogen_total', 'Protein_videnskabelig', 'Protein_deklaration', 'Kulhydrat_difference ',
       ...
       'Arginin', 'Histidin', 'Alanin', 'Asparaginsyre', 'Glutaminsyre',
       'Glycin', 'Prolin', 'Hydroxyprolin', 'Serin', 'Massefylde']
"""
#,  skiprows=1, names= col_names 
data= pd.read_excel(data_link, sheet_name=1, index_col=0, header=0, skiprows=0).round(decimals = 2)
data.head()
# Out:
#                      Unnamed: 1             Unnamed: 2 Svind Energi, kJ  \
# Nummer                   gruppe                   Navn     %         kJ
# 1                      Bærfrugt            Jordbær, rå     4        162
# 2                    Kernefrugt      Æble, uspec., råt    10        233
# 3                      Sydfrugt              Banan, rå    41        396
# 4       Rod- og knoldgrøntsager  Kartoffel, uspec., rå    25        326
#
#        Energi, kcal Nitrogen-til-protein faktor Nitrogen, total  \
# Nummer         kcal                           -               g
# 1                38                        6.25           0.106
# 2                55                        6.25           0.043
# 3                93                        6.25           0.183
# 4                77                        6.25           0.324
#
#        Protein, videnskabelig Protein, deklaration Kulhydrat, difference   \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1187 entries, Nummer to 1730
# Columns: 201 entries, Unnamed: 1 to Massefylde
# dtypes: object(201)
# memory usage: 1.8+ MB

# %%
print(data.columns)
# Out:
# Index(['Unnamed: 1', 'Unnamed: 2', 'Svind', 'Energi, kJ', 'Energi, kcal',
#        'Nitrogen-til-protein faktor', 'Nitrogen, total',
#        'Protein, videnskabelig', 'Protein, deklaration',
#        'Kulhydrat, difference ',
#        ...
#        'Arginin', 'Histidin', 'Alanin', 'Asparaginsyre', 'Glutaminsyre',
#        'Glycin', 'Prolin', 'Hydroxyprolin', 'Serin', 'Massefylde'],
#       dtype='object', length=201)
